# %%
import pandas as pd

# %%
data = pd.read_csv('heart.csv')

# %%
data_continuous = data[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'ca']]

# %%
data_continuous
# Out:
#       age  trestbps  chol  thalach  oldpeak  ca
# 0      52       125   212      168      1.0   2
# 1      53       140   203      155      3.1   0
# 2      70       145   174      125      2.6   0
# 3      61       148   203      161      0.0   1
# 4      62       138   294      106      1.9   3
# ...   ...       ...   ...      ...      ...  ..
# 1020   59       140   221      164      0.0   0
# 1021   60       125   258      141      2.8   1
# 1022   47       110   275      118      1.0   1
# 1023   50       110   254      159      0.0   0
# 1024   54       120   188      113      1.4   1
#
# [1025 rows x 6 columns]

# %%
data_continuous.mean()  # Média
# Out:
# age          54.434146
# trestbps    131.611707
# chol        246.000000
# thalach     149.114146
# oldpeak       1.071512
# ca            0.754146
# dtype: float64

# %%
data_continuous.mode()  # Moda
# Out:
#     age  trestbps  chol  thalach  oldpeak   ca
# 0  58.0     120.0   204    162.0      0.0  0.0
# 1   NaN       NaN   234      NaN      NaN  NaN

# %%
data_continuous.var()  # Variância
# Out:
# age           82.306450
# trestbps     306.835410
# chol        2661.787109
# thalach      529.263325
# oldpeak        1.380750
# ca             1.062544
# dtype: float64

# %%
data_continuous.std()  # Desvio padrão
# Out:
# age          9.072290
# trestbps    17.516718
# chol        51.592510
# thalach     23.005724
# oldpeak      1.175053
# ca           1.030798
# dtype: float64

# %%
data_continuous.describe()
# Out:
#                age     trestbps        chol      thalach      oldpeak  \
# count  1025.000000  1025.000000  1025.00000  1025.000000  1025.000000
# mean     54.434146   131.611707   246.00000   149.114146     1.071512
# std       9.072290    17.516718    51.59251    23.005724     1.175053
# min      29.000000    94.000000   126.00000    71.000000     0.000000
# 25%      48.000000   120.000000   211.00000   132.000000     0.000000
# 50%      56.000000   130.000000   240.00000   152.000000     0.800000
# 75%      61.000000   140.000000   275.00000   166.000000     1.800000
# max      77.000000   200.000000   564.00000   202.000000     6.200000
#
#                 ca
# count  1025.000000
# mean      0.754146
# std       1.030798
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       4.000000

# %%
bp = data_continuous.boxplot(column=['oldpeak'])

# %%
hist = data.hist(column=['sex'])

# %%
hist = data.hist(column=['cp', 'fbs', 'exang', 'slope', 'thal', 'target'])
